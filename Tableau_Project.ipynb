# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsha-811/-Customer-Churn-Analysis-Dashboard-Telecom-Sector-/blob/main/Tableau_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Retention & Churn Prediction Dashboard
#
# #  "churn" refers to the rate at which customers stop using a company's product or service within a given period

# %% [markdown]
# Importing The Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Uploading The File from Local System

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d3f5b88-4c1a-4a43-b9a2-74b6754a4e82" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d3f5b88-4c1a-4a43-b9a2-74b6754a4e82">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# For Analysis

# %%
df= pd.read_csv('customer_churn_dataset.csv')
df
# Out:
#     Customer ID   Join Date Region      Segment  Total Spend  Support Tickets  \
# 0      CUST0001  2020-07-27   East    Corporate      2248.85                1
# 1      CUST0002  2022-03-05   West  Home Office      4764.79                2
# 2      CUST0003  2020-04-09  North     Consumer        63.49                0
# 3      CUST0004  2023-09-28   East     Consumer      2144.78                1
# 4      CUST0005  2021-11-24   East     Consumer       725.83                4
# ..          ...         ...    ...          ...          ...              ...
# 995    CUST0996  2023-10-30  North    Corporate      1067.50                0
# 996    CUST0997  2024-08-17  North    Corporate       139.06                1
# 997    CUST0998  2024-04-14   West    Corporate      1161.11                1
# 998    CUST0999  2020-12-31   West     Consumer        97.65                1
# 999    CUST1000  2023-08-21   East     Consumer        29.80                3
#
# ...

# %% [markdown]
# ###Head Defines for top Rows

# %%
df.head()
# Out:
#   Customer ID   Join Date Region      Segment  Total Spend  Support Tickets  \
# 0    CUST0001  2020-07-27   East    Corporate      2248.85                1
# 1    CUST0002  2022-03-05   West  Home Office      4764.79                2
# 2    CUST0003  2020-04-09  North     Consumer        63.49                0
# 3    CUST0004  2023-09-28   East     Consumer      2144.78                1
# 4    CUST0005  2021-11-24   East     Consumer       725.83                4
#
#    Discount Used (%)  Engagement Score  Satisfaction Score Last Purchase Date  \
# 0               25.1              3.66                 3.5         2022-03-31
# 1               16.3              1.82                 2.0         2024-07-28
# 2               11.2              7.01                 4.2         2021-09-11
# 3               18.8              2.20                 3.5         2025-04-04
# 4                0.4              8.67                 3.0         2025-04-03
#
#    Tenure (days)  Recency (days)  Churn
# ...

# %% [markdown]
# ### (Info) defines for the Data Type of variables and List of Coloumns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         1000 non-null   object
#  1   Join Date           1000 non-null   object
#  2   Region              1000 non-null   object
#  3   Segment             1000 non-null   object
#  4   Total Spend         1000 non-null   float64
#  5   Support Tickets     1000 non-null   int64
#  6   Discount Used (%)   1000 non-null   float64
#  7   Engagement Score    1000 non-null   float64
#  8   Satisfaction Score  1000 non-null   float64
#  9   Last Purchase Date  1000 non-null   object
#  10  Tenure (days)       1000 non-null   int64
#  11  Recency (days)      1000 non-null   int64
#  12  Churn               1000 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 101.7+ KB

# %% [markdown]
# # Checking for missing values

# %%
df.isnull().sum()
# Out:
# Customer ID           0
# Join Date             0
# Region                0
# Segment               0
# Total Spend           0
# Support Tickets       0
# Discount Used (%)     0
# Engagement Score      0
# Satisfaction Score    0
# Last Purchase Date    0
# Tenure (days)         0
# Recency (days)        0
# Churn                 0
# dtype: int64

# %% [markdown]
# # Churn Distribution

# %%
df['Churn'].value_counts(normalize=True) * 100
# Out:
# Churn
# 1    51.0
# 0    49.0
# Name: proportion, dtype: float64

# %% [markdown]
# # Region vs Churn

# %%
region_churn = df.groupby('Region')['Churn'].mean().sort_values(ascending=False)
print(region_churn)
# Out:
# Region
# South    0.526087
# East     0.521552
# West     0.514286
# North    0.480620
# Name: Churn, dtype: float64

# %% [markdown]
# # Engagement vs Churn

# %%
df.groupby('Churn')['Engagement Score'].mean()
# Out:
# Churn
# 0    6.621980
# 1    4.182843
# Name: Engagement Score, dtype: float64

# %% [markdown]
# # Satisfaction vs Churn

# %%
df.groupby('Churn')['Satisfaction Score'].mean()
# Out:
# Churn
# 0    3.504286
# 1    2.553137
# Name: Satisfaction Score, dtype: float64

# %% [markdown]
# # we are exporting and cleaned filtered version for Tableau:

# %%
df['Churn Risk Level'] = df['Churn'].apply(lambda x: 'High' if x == 1 else 'Low')

# Save to new CSV
df.to_csv("tableau_churn_data.csv", index=False)

# %% [markdown]
# # Downloading the file Using Tableau

# %%
from google.colab import files
files.download("tableau_churn_data.csv")
